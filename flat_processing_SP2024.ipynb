# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import ccdproc as ccdp
from ccdproc import trim_image
from ccdproc import subtract_overscan

import os

import pickle as pickle

from photutils.detection import DAOStarFinder
from photutils.aperture import CircularAperture, CircularAnnulus, aperture_photometry

from astropy.io import fits
from astropy import units as u
from astropy.nddata import CCDData
from astropy.stats import sigma_clipped_stats
from astropy.modeling.models import Gaussian2D

from astropy.visualization import make_lupton_rgb, SqrtStretch, ZScaleInterval

import scipy.ndimage.interpolation as interp

import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
raw_dir='/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/'
overscan_dir='/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/overscan_sub/'
reduced_dir='/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/'

# %% [markdown]
# ### Perform overscan subtraction (i.e., bias subtraction)

# %% [markdown]
# First, let's define a function to perform overscan subtraction and trimming of all images.

# %%
def overscan_subtraction(infiles, outdir):
    if(not outdir.endswith('/')): outdir=outdir+'/'
    if(not os.path.exists(outdir)): os.mkdir(outdir)
    
    #Scan inbox directory for .fit files
    for image in infiles:
        outfile=outdir+os.path.split(image)[1]  #Define output file
        print('Processing image '+image)
           
        #Generate a CCDData object from the image's data array
        hdul = fits.open(image)
        ccddata = CCDData(hdul[0].data, unit=u.adu)

        #subtract overscan row-by-row and crop region
        overscan_subtracted_data = subtract_overscan(ccddata, overscan=ccddata[:, 0:50]) #Only using left overscan
        overscan_subtracted_trimmed_data = np.asarray(trim_image(overscan_subtracted_data[:, 50:2098]))
            
        #Update header information for image width
        header = hdul[0].header
        header['NAXIS1'] = 2048
        header['IMAGEW'] = 2048
    
        #Save data to outbox directory.
        hdul[0].data = overscan_subtracted_trimmed_data
        hdul.writeto(outfile,overwrite=True)

# %% [markdown]
# We need to define our input files, and our output directory.

# %%
#Create the list of input files
indir=raw_dir  
filelist=[]
for file in os.listdir(indir):
    if(file.endswith("b.fit") or file.endswith("d.fit") or file.endswith("r.fit") or
       file.endswith("v.fit") or file.endswith("i.fit")): #Find all image and dark files
           filelist.append(os.path.join(indir, file))

#Define the output directory  
outdir=overscan_dir  
print('output directory:', outdir)
#print(filelist)  #Run this command to check your list of files
# Out:
# output directory: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/overscan_sub/

# %%
#Run overscan subtraction on filelist
overscan_subtraction(filelist, outdir)
# Out:
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-003i.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-001v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-004i.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-016d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-001b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-020d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-010b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-007b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-021d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-001d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-017d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-011v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-005i.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-001r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-002i.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-007b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-026d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-030d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-011b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-007v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-005i.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-006r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-017r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-010r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-010d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-006d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-007d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-011d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-011r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-016r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-003i.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-006v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-007r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-004i.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-010b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-027d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-006b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-008i.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-008d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-013b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-024d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-005b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-009v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-008r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-004d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-012d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-012r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-014v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-015r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-028d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-004r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-007i.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-005v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-009b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-008b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-006i.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-005r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-004v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-029d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-013d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-005d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-008v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-009r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-004b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-025d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-012b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-009d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-002d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-014d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-012v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-006i.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-008b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-003v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-002r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-001i.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-018d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-022d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-003b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-002b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-023d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-014b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-019d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-002v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-003r.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-009b.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24M25-013v.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-015d.fit
# Processing image /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/raw/24mar25-003d.fit

# %% [markdown]
# Do a visual inspection to make sure the routine worked as expected, and that your overscan-subtrated image has the correct size (2048 x 2048).
#
# *You will need to replace the presub and postsub file names with your file names!*

# %%
presub_file=raw_dir+'24mar25-001i.fit' #Replace!!
postsub_file=overscan_dir+'24mar25-001i.fit' #Replace!!
presub_hdul = fits.open(presub_file)   #Read in pre-subtraction image
postsub_hdul = fits.open(postsub_file) #Read in post-subtraction image
presub_img = presub_hdul[0].data
postsub_img = postsub_hdul[0].data

fig=plt.figure(figsize=(12,3))

#Plot pre-sub image
ax1=fig.add_subplot(131)
ax1.imshow(presub_img, cmap='gray',vmin=np.median(presub_img)*0.7, vmax=np.median(presub_img)*1.3)

#Plot post-sub image
ax2=fig.add_subplot(132)
ax2.imshow(postsub_img, cmap='gray',vmin=np.median(postsub_img)*0.7, vmax=np.median(postsub_img)*1.3)

#Plot one row of each image, to compare
ax3=fig.add_subplot(133)
ax3.plot(presub_img[1250,:],label='pre-sub')
ax3.plot(postsub_img[1250,:],label='post-sub')
ax3.legend()
ax3.set_xlabel('pixel')
ax3.set_ylabel('value')

print('Shapes of images: ',np.shape(presub_img),np.shape(postsub_img))
print('Mean values in images:', np.mean(presub_img),np.mean(postsub_img))
# Out:
# Shapes of images:  (2048, 2148) (2048, 2048)
# Mean values in images: 2484.2381118973317 201.5308752155303

# %% [markdown]
# ### Create a master dark

# %% [markdown]
# First inspect exposure times to decide on strategy.
#
# Option 1: Average all dark frames with same exposure time as science frames.
#
# Option 2: Subtract bias from all dark frames, then scale by exposure time for each science frame.

# %%
#Inspect all images to look at exposure times of science and dark frames
dark_ifc = ccdp.ImageFileCollection(overscan_dir,glob_include='*d.fit')  #Find all darks
dark_ifc.summary['file','imagetyp','exptime'].show_in_notebook()

#Dark frames have a range of exposure times, and only some match our flats.
#I'm going to make an average of the 30s darks, and then scale those later to 
#match the science exposure times
# Out:
# <i>Table length=30</i>
# <table id="table4793908112-802699" class="table-striped table-bordered table-condensed">
# <thead><tr><th>idx</th><th>file</th><th>imagetyp</th><th>exptime</th></tr></thead>
# <tr><td>0</td><td>24mar25-001d.fit</td><td>Dark Frame</td><td>4.0</td></tr>
# <tr><td>1</td><td>24mar25-002d.fit</td><td>Dark Frame</td><td>4.0</td></tr>
# <tr><td>2</td><td>24mar25-003d.fit</td><td>Dark Frame</td><td>4.0</td></tr>
# <tr><td>3</td><td>24mar25-004d.fit</td><td>Dark Frame</td><td>4.0</td></tr>
# <tr><td>4</td><td>24mar25-005d.fit</td><td>Dark Frame</td><td>4.0</td></tr>
# <tr><td>5</td><td>24mar25-006d.fit</td><td>Dark Frame</td><td>15.0</td></tr>
# <tr><td>6</td><td>24mar25-007d.fit</td><td>Dark Frame</td><td>15.0</td></tr>
# <tr><td>7</td><td>24mar25-008d.fit</td><td>Dark Frame</td><td>15.0</td></tr>
# <tr><td>8</td><td>24mar25-009d.fit</td><td>Dark Frame</td><td>15.0</td></tr>
# <tr><td>9</td><td>24mar25-010d.fit</td><td>Dark Frame</td><td>15.0</td></tr>
# <tr><td>10</td><td>24mar25-011d.fit</td><td>Dark Frame</td><td>30.0</td></tr>
# <tr><td>11</td><td>24mar25-012d.fit</td><td>Dark Frame</td><td>30.0</td></tr>
# <tr><td>12</td><td>24mar25-013d.fit</td><td>Dark Frame</td><td>30.0</td></tr>
# <tr><td>13</td><td>24mar25-014d.fit</td><td>Dark Frame</td><td>30.0</td></tr>
# <tr><td>14</td><td>24mar25-015d.fit</td><td>Dark Frame</td><td>30.0</td></tr>
# <tr><td>15</td><td>24mar25-016d.fit</td><td>Dark Frame</td><td>60.0</td></tr>
# <tr><td>16</td><td>24mar25-017d.fit</td><td>Dark Frame</td><td>60.0</td></tr>
# <tr><td>17</td><td>24mar25-018d.fit</td><td>Dark Frame</td><td>60.0</td></tr>
# <tr><td>18</td><td>24mar25-019d.fit</td><td>Dark Frame</td><td>60.0</td></tr>
# <tr><td>19</td><td>24mar25-020d.fit</td><td>Dark Frame</td><td>60.0</td></tr>
# <tr><td>20</td><td>24mar25-021d.fit</td><td>Dark Frame</td><td>75.0</td></tr>
# <tr><td>21</td><td>24mar25-022d.fit</td><td>Dark Frame</td><td>75.0</td></tr>
# <tr><td>22</td><td>24mar25-023d.fit</td><td>Dark Frame</td><td>75.0</td></tr>
# <tr><td>23</td><td>24mar25-024d.fit</td><td>Dark Frame</td><td>75.0</td></tr>
# <tr><td>24</td><td>24mar25-025d.fit</td><td>Dark Frame</td><td>75.0</td></tr>
# <tr><td>25</td><td>24mar25-026d.fit</td><td>Dark Frame</td><td>2.0</td></tr>
# <tr><td>26</td><td>24mar25-027d.fit</td><td>Dark Frame</td><td>2.0</td></tr>
# <tr><td>27</td><td>24mar25-028d.fit</td><td>Dark Frame</td><td>2.0</td></tr>
# <tr><td>28</td><td>24mar25-029d.fit</td><td>Dark Frame</td><td>2.0</td></tr>
# <tr><td>29</td><td>24mar25-030d.fit</td><td>Dark Frame</td><td>2.0</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table4793908112-802699').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table4793908112-802699').dataTable({
#         order: [],
#         pageLength: 50,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [0, 3], type: "optionalnum"}]
#     });
# });
# </script>

# %% [markdown]
# Combine darks into a master dark

# %%
#ID all dark files with 30s exposures
dark_ifc=ccdp.ImageFileCollection(overscan_dir,glob_include='*d.fit')
dark_files = dark_ifc.files_filtered(exptime=30.0)  #extract all darks with 30s exposures

#Read in all of these darks
dark_list=[]
for mydark in dark_files:
    print("Reading",mydark)
    dark_ccd=CCDData.read(overscan_dir+mydark, unit="adu")     
    dark_list.append(dark_ccd)

#Combine all darks and write to file
combined_dark = ccdp.combine(dark_list, unit='adu', method='average',
                             output_file=overscan_dir+'master_dark_30s.fit',overwrite_output=True)
# Out:
# Reading 24mar25-011d.fit
# Reading 24mar25-012d.fit
# Reading 24mar25-013d.fit
# Reading 24mar25-014d.fit
# Reading 24mar25-015d.fit

# %% [markdown]
# Inspect images to make sure they make some sense. The master dark should have lower noise

# %%
master_dark_file=overscan_dir+'master_dark_30s.fit' #Read in master dark image
master_dark_hdul = fits.open(master_dark_file)   
master_dark_img = master_dark_hdul[0].data

dark_file=overscan_dir+'24mar25-011d.fit'  #Read in single dark image
dark_hdul = fits.open(dark_file)
dark_img = dark_hdul[0].data

fig=plt.figure(figsize=(12,3))
#Plot bias image
ax1=fig.add_subplot(131)
ax1.imshow(dark_img, cmap='gray',vmin=-80, vmax=80)
ax2=fig.add_subplot(132)
ax2.imshow(master_dark_img, cmap='gray',vmin=-50, vmax=50)

#Plot one row of each image, to compare
ax3=fig.add_subplot(133)
ax3.plot(dark_img[1250,:],label='Single')
ax3.plot(master_dark_img[1250,:],label='Master')
ax3.legend()
ax3.set_xlabel('pixel')
ax3.set_ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %% [markdown]
# ### Process V flats

# %% [markdown]
# Reduce V flat files

# %%
#First, select all V-filter flats (Use the log to select!)
science_ifc=ccdp.ImageFileCollection(overscan_dir,filenames=['24M25-011v.fit','24M25-012v.fit',
                                                             '24M25-013v.fit', '24M25-014v.fit'])
science_files = science_ifc.files_filtered()

#Read master dark
master_dark_file=overscan_dir+'master_dark_60s.fit' 
master_dark_ccd=CCDData.read(master_dark_file, unit="adu")

#Process flats
for i, myfile in enumerate(science_files):
    print("Processing ", myfile)
    science_ccd = CCDData.read(overscan_dir+myfile, unit="adu") 
 
    #Subtract the dark from the flat image
    reduced_ccd = ccdp.subtract_dark(science_ccd, master_dark_ccd,
                                      exposure_time='EXPTIME', #Name of exposure time in header
                                      exposure_unit=u.second, scale=True)
    #Make sure to set scale=True since the data and darks have different exposure times
    
    #Divide each image by median so they're on the same scale
    factor=1./np.median(reduced_ccd.data) #Compute median
    reduced_ccd=reduced_ccd.multiply(factor * u.adu)
    
    #Write file out
    outfile=reduced_dir+myfile
    print("Writing reduced image data to:",outfile)
    reduced_ccd.write(outfile,overwrite=True)
# Out:
# INFO:astropy:using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# Processing  24M25-011v.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-011v.fit
# Processing  24M25-012v.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-012v.fit
# Processing  24M25-013v.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-013v.fit
# Processing  24M25-014v.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-014v.fit

# %% [markdown]
# Combine V flats

# %%
#Define the list of *reduced* V flats (same names as above, but now the reduced directory)
#I'm not usinv 13v.fit because it overlaps too closely with another image
#I'm also using an odd number, so the median will (hopefully) not include any stars
Vflat_ifc=ccdp.ImageFileCollection(reduced_dir,filenames=['24M25-011v.fit','24M25-012v.fit', '24M25-014v.fit'])
Vflat_files = Vflat_ifc.files_filtered(include_path=True)
print("To be combined:")
print(Vflat_files)

combined_Vflat = ccdp.combine(Vflat_files,method='median')
combined_Vflat.write(reduced_dir+'vFLAT.fit',overwrite=True)
# Out:
# To be combined:
# ['/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-011v.fit', '/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-012v.fit', '/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-014v.fit']

# %% [markdown]
# Inspect

# %%
master_flat_file=reduced_dir+'vFLAT.fit' #Read in master flat image
master_flat_hdul = fits.open(master_flat_file)   
master_flat_img = master_flat_hdul[0].data

flat_file=overscan_dir+'24M25-011v.fit' #Read in single flat image
flat_hdul = fits.open(flat_file)
flat_img = flat_hdul[0].data

fig=plt.figure(figsize=(14,7))
#Plot flat image
ax1=fig.add_subplot(131)
ax1.imshow(flat_img, cmap='gray',vmin=np.median(flat_img)*0.7, vmax=np.median(flat_img)*1.3)
ax2=fig.add_subplot(132)
ax2.imshow(master_flat_img, cmap='gray',vmin=np.median(master_flat_img)*0.7, vmax=np.median(master_flat_img)*1.3)

#Plot one row 
ax3=fig.add_subplot(133)
ax3.plot(flat_img[1250,:]/np.median(flat_img),label='individual')
ax3.plot(master_flat_img[1250,:],label='Master')
ax3.legend()
ax3.set_xlabel('pixel')
ax3.set_ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %% [markdown]
# ### Process B flats

# %% [markdown]
# Reduce B flat files

# %%
#First, select all V-filter flats (Use the log to select!)
science_ifc=ccdp.ImageFileCollection(overscan_dir,filenames=['24M25-007b.fit','24M25-008b.fit',
                                                             '24M25-009b.fit','24M25-010b.fit'])
science_files = science_ifc.files_filtered()

#Read master dark
master_dark_file=overscan_dir+'master_dark_60s.fit' 
master_dark_ccd=CCDData.read(master_dark_file, unit="adu")

#Process flats
for i, myfile in enumerate(science_files):
    print("Processing ", myfile)
    science_ccd = CCDData.read(overscan_dir+myfile, unit="adu") 
 
    #Subtract the dark from the flat image
    reduced_ccd = ccdp.subtract_dark(science_ccd, master_dark_ccd,
                                      exposure_time='EXPTIME', #Name of exposure time in header
                                      exposure_unit=u.second, scale=True)
    #Make sure to set scale=True since the data and darks have different exposure times
    
    #Divide each image by median so they're on the same scale
    factor=1./np.median(reduced_ccd.data) #Compute median
    reduced_ccd=reduced_ccd.multiply(factor * u.adu)
    
    #Write file out
    outfile=reduced_dir+myfile
    print("Writing reduced image data to:",outfile)
    reduced_ccd.write(outfile,overwrite=True)
# Out:
# INFO:astropy:using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# Processing  24M25-007b.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-007b.fit
# Processing  24M25-008b.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-008b.fit
# Processing  24M25-009b.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-009b.fit
# Processing  24M25-010b.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-010b.fit

# %% [markdown]
# Combine B flats

# %%
#Define the list of *reduced* V flats (same names as above, but now the reduced directory)
#I'm not usinv 13v.fit because it overlaps too closely with another image
#I'm also using an odd number, so the median will (hopefully) not include any stars
Vflat_ifc=ccdp.ImageFileCollection(reduced_dir,filenames=['24M25-007b.fit','24M25-008b.fit','24M25-010b.fit'])
Vflat_files = Vflat_ifc.files_filtered(include_path=True)
print("To be combined:")
print(Vflat_files)

combined_Vflat = ccdp.combine(Vflat_files,method='median')
combined_Vflat.write(reduced_dir+'bFLAT.fit',overwrite=True)
# Out:
# To be combined:
# ['/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-007b.fit', '/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-008b.fit', '/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-010b.fit']

# %% [markdown]
# Inspect B flats

# %%
master_flat_file=reduced_dir+'bFLAT.fit' #Read in master flat image
master_flat_hdul = fits.open(master_flat_file)   
master_flat_img = master_flat_hdul[0].data

flat_file=overscan_dir+'24M25-007b.fit'  #Read in single flat image
flat_hdul = fits.open(flat_file)
flat_img = flat_hdul[0].data

fig=plt.figure(figsize=(14,7))
#Plot flat image
ax1=fig.add_subplot(131)
ax1.imshow(flat_img, cmap='gray',vmin=np.median(flat_img)*0.7, vmax=np.median(flat_img)*1.3)
ax2=fig.add_subplot(132)
ax2.imshow(master_flat_img, cmap='gray',vmin=np.median(master_flat_img)*0.7, vmax=np.median(master_flat_img)*1.3)

#Plot one row 
ax3=fig.add_subplot(133)
ax3.plot(flat_img[1250,:]/np.median(flat_img),label='individual')
ax3.plot(master_flat_img[1250,:],label='Master')
ax3.legend()
ax3.set_xlabel('pixel')
ax3.set_ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %% [markdown]
# ### Process R flats

# %% [markdown]
# Reduce R flat files

# %%
#First, select all V-filter flats (Use the log to select!)
science_ifc=ccdp.ImageFileCollection(overscan_dir,filenames=['24M25-015r.fit','24M25-016r.fit',
                                                            '24M25-017r.fit'])
science_files = science_ifc.files_filtered()

#Read master dark
master_dark_file=overscan_dir+'master_dark_60s.fit' 
master_dark_ccd=CCDData.read(master_dark_file, unit="adu")

#Process flats
for i, myfile in enumerate(science_files):
    print("Processing ", myfile)
    science_ccd = CCDData.read(overscan_dir+myfile, unit="adu") 
 
    #Subtract the dark from the flat image
    reduced_ccd = ccdp.subtract_dark(science_ccd, master_dark_ccd,
                                      exposure_time='EXPTIME', #Name of exposure time in header
                                      exposure_unit=u.second, scale=True)
    #Make sure to set scale=True since the data and darks have different exposure times
    
    #Divide each image by median so they're on the same scale
    factor=1./np.median(reduced_ccd.data) #Compute median
    reduced_ccd=reduced_ccd.multiply(factor * u.adu)
    
    #Write file out
    outfile=reduced_dir+myfile
    print("Writing reduced image data to:",outfile)
    reduced_ccd.write(outfile,overwrite=True)
# Out:
# INFO:astropy:using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# Processing  24M25-015r.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-015r.fit
# Processing  24M25-016r.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-016r.fit
# Processing  24M25-017r.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-017r.fit

# %% [markdown]
# Combine R flats

# %%
#Define the list of *reduced* V flats (same names as above, but now the reduced directory)
#I'm not usinv 13v.fit because it overlaps too closely with another image
#I'm also using an odd number, so the median will (hopefully) not include any stars
Vflat_ifc=ccdp.ImageFileCollection(reduced_dir,filenames=['24M25-015r.fit','24M25-016r.fit',
                                                          '24M25-017r.fit'])
Vflat_files = Vflat_ifc.files_filtered(include_path=True)
print("To be combined:")
print(Vflat_files)

combined_Vflat = ccdp.combine(Vflat_files,method='median')
combined_Vflat.write(reduced_dir+'rFLAT.fit',overwrite=True)
# Out:
# To be combined:
# ['/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-015r.fit', '/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-016r.fit', '/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-017r.fit']

# %% [markdown]
# Inspect R flats

# %%
master_flat_file=reduced_dir+'rFLAT.fit' #Read in master flat image
master_flat_hdul = fits.open(master_flat_file)   
master_flat_img = master_flat_hdul[0].data

flat_file=overscan_dir+'24M25-015r.fit'  #Read in single flat image
flat_hdul = fits.open(flat_file)
flat_img = flat_hdul[0].data

fig=plt.figure(figsize=(14,7))
#Plot flat image
ax1=fig.add_subplot(131)
ax1.imshow(flat_img, cmap='gray',vmin=np.median(flat_img)*0.7, vmax=np.median(flat_img)*1.3)
ax2=fig.add_subplot(132)
ax2.imshow(master_flat_img, cmap='gray',vmin=np.median(master_flat_img)*0.7, vmax=np.median(master_flat_img)*1.3)

#Plot one row 
ax3=fig.add_subplot(133)
ax3.plot(flat_img[1250,:]/np.median(flat_img),label='individual')
ax3.plot(master_flat_img[1250,:],label='Master')
ax3.legend()
ax3.set_xlabel('pixel')
ax3.set_ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %% [markdown]
# ### Process I flats

# %% [markdown]
# Reduce I flat files

# %%
#First, select all V-filter flats (Use the log to select!)
science_ifc=ccdp.ImageFileCollection(overscan_dir,filenames=['24M25-003i.fit','24M25-004i.fit',
                                                             '24M25-005i.fit','24M25-006i.fit'])
science_files = science_ifc.files_filtered()

#Read master dark
master_dark_file=overscan_dir+'master_dark_60s.fit' 
master_dark_ccd=CCDData.read(master_dark_file, unit="adu")

#Process flats
for i, myfile in enumerate(science_files):
    print("Processing ", myfile)
    science_ccd = CCDData.read(overscan_dir+myfile, unit="adu") 
 
    #Subtract the dark from the flat image
    reduced_ccd = ccdp.subtract_dark(science_ccd, master_dark_ccd,
                                      exposure_time='EXPTIME', #Name of exposure time in header
                                      exposure_unit=u.second, scale=True)
    #Make sure to set scale=True since the data and darks have different exposure times
    
    #Divide each image by median so they're on the same scale
    factor=1./np.median(reduced_ccd.data) #Compute median
    reduced_ccd=reduced_ccd.multiply(factor * u.adu)
    
    #Write file out
    outfile=reduced_dir+myfile
    print("Writing reduced image data to:",outfile)
    reduced_ccd.write(outfile,overwrite=True)
# Out:
# INFO:astropy:using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# Processing  24M25-003i.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-003i.fit
# Processing  24M25-004i.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-004i.fit
# Processing  24M25-005i.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-005i.fit
# Processing  24M25-006i.fit
# Writing reduced image data to: /Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-006i.fit

# %% [markdown]
# Combine I flats

# %%
#Define the list of *reduced* V flats (same names as above, but now the reduced directory)
#I'm not usinv 13v.fit because it overlaps too closely with another image
#I'm also using an odd number, so the median will (hopefully) not include any stars
Vflat_ifc=ccdp.ImageFileCollection(reduced_dir,filenames=['24M25-003i.fit','24M25-004i.fit','24M25-006i.fit'])
Vflat_files = Vflat_ifc.files_filtered(include_path=True)
print("To be combined:")
print(Vflat_files)

combined_Vflat = ccdp.combine(Vflat_files,method='median')
combined_Vflat.write(reduced_dir+'iFLAT.fit',overwrite=True)
# Out:
# To be combined:
# ['/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-003i.fit', '/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-004i.fit', '/Users/mariahjones/Desktop/Research/projects/ASTR240/MCI/reduced/24M25-006i.fit']

# %% [markdown]
# Inspect I flats

# %%
master_flat_file=reduced_dir+'iFLAT.fit' #Read in master flat image
master_flat_hdul = fits.open(master_flat_file)   
master_flat_img = master_flat_hdul[0].data

flat_file=overscan_dir+'24M25-003i.fit'  #Read in single flat image
flat_hdul = fits.open(flat_file)
flat_img = flat_hdul[0].data

fig=plt.figure(figsize=(14,7))
#Plot flat image
ax1=fig.add_subplot(131)
ax1.imshow(flat_img, cmap='gray',vmin=np.median(flat_img)*0.7, vmax=np.median(flat_img)*1.3)
ax2=fig.add_subplot(132)
ax2.imshow(master_flat_img, cmap='gray',vmin=np.median(master_flat_img)*0.7, vmax=np.median(master_flat_img)*1.3)

#Plot one row 
ax3=fig.add_subplot(133)
ax3.plot(flat_img[1250,:]/np.median(flat_img),label='individual')
ax3.plot(master_flat_img[1250,:],label='Master')
ax3.legend()
ax3.set_xlabel('pixel')
ax3.set_ylabel('value')
# Out:
# Text(0, 0.5, 'value')
